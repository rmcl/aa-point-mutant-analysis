# %%
import json

data = []
with open('/home/rmcl/parisahlab/rmcl/gce-pThr/round1-job-runs-priorto-9-25/Y5-singleaa-mutants-pThr-5-8-25/outputs-pThr/aasingle-scores.jsonl', 'r') as fp:
    for line in fp:
        row = json.loads(line)
        data.append(row)

# %%
import pandas as pd

# %%
pd.DataFrame(data)
# Out:
#     mutated_aa  residue_position  total_score  interface_total_score  \
# 0            Y               275  -609.579657            -146.868017
# 1            T               228  -612.086944            -151.324305
# 2            P               186  -612.180108            -142.181168
# 3            K               234  -622.991378            -151.252555
# 4            F               229  -614.648705            -152.866298
# ..         ...               ...          ...                    ...
# 395          I               270  -617.397591            -147.323867
# 396          E               275  -598.258130            -137.426232
# 397          Y               256  -621.237296            -161.085364
# 398          E               256  -610.043422            -128.703636
# 399          S               274  -614.985848            -154.911751
#
#      interface_fa_atr  interface_fa_rep  interface_fa_sol  \
# 0         -445.048688         93.500434        301.600993
# ...
